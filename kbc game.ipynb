# %%
questions=[["Identify the full form of HTTP?","HyperText Transfer protocol","HyperText Transfer package","Hyper Tranfer Text Package","Hyper Transfer Text Practice","none",1],
           ["Usually,for which of these from a bank you would to provide a collateral?","Savings account","Locker","Loan",  "ATM card","none",3],
           ["Identify the total versions of IP.?","1","2","3","4","none",2],
           ["What is the full form of OSI?","optical service implementation","open service Internet","open system interconnection","operating system interface","none",3],
           ["How many layers are there in the ISO OSI reference model?","7","5","4","6","none",1],
           ["The language of Lakshadweep. a Union Territory of India, is?","Tamil","Hindi","Malayalam","Telugu","none",3],
           ["A byte corresponds to a cluster of how many bits?","12","15","14","8","none",4],
           ["CPU is also referred to as?","Micro chip","Microprocessor","Decoder","Coder","none",2],
           ["The full form of GB is?","Giga Bar","Giga Byte","Giga Boot","Giga Bot","none",2],
           ["Which is the 'fibre' used to make bulletproof jackets?","Nylon","Terylene","Tweed","Kevlar","none",4],
           ["When was Champaran Satyagraha started?","1916","1917","1920","1921","none",2],
           ["The full form of WWW is?","World Website Web","World Wide Web","World Widely Web","World Wing Web","none",2],
           ["The full form of RAM is?","Random Appliance Machine","Read Access Manual","Real Absolute Memory","Random Access Memory","none",4],
           ["What does Fn mean in Fn key of the computer keyboard?","Finish","Function","Final","Fun","none",2],
           ["In computing, DEL is a short form of?","Digital Execution Language","Delete","Device Execute Language","Dynamic Extract Language","none",2],
           
           ]

levels = [0,1000,2000,3000,5000,10000,20000,40000,80000,160000,320000,640000,1250000,2500000,5000000,7500000,10000000,70000000]

money = 0
print("Welcome to Kaun Bnega Crorepati!.....Let's Play")
for i in range(0, len(questions)):
  
  question = questions[i]
  print(f"\n\nQuestion for Rs. {levels[i+1]}")
  print(f"{question[0]}")
  print(f"a.{question[1]}          b.{question[2]} ")
  print(f"c.{question[3]}           d.{question[4]} ")
  reply = int(input("Enter your answer (1-4) or  0 to quit:\n" ))
  if (reply == 0):
    money = levels[i]
    print(f"You chose to quit, you have won Rs. {money}" )
    break
  if(reply == question[-1]):
    print(f"Correct answer, you have won Rs. {levels[i+1]}")
    if(i == 5):
      money = 10000
    elif(i == 10):
      money = 320000
    elif(i == 15):
      money = 7500000
    elif(i==17):
        print("Congratulations,You have become Crorepati")
  else:
    print("Wrong answer!")
    break 
print(f"Money you won is {money}")
# Out:
# Welcome to Kaun Bnega Crorepati!.....Let's Play
#
#
# Question for Rs. 1000
# Identify the full form of HTTP?
# a.HyperText Transfer protocol          b.HyperText Transfer package
# c.Hyper Tranfer Text Package           d.Hyper Transfer Text Practice
# Enter your answer (1-4) or  0 to quit:
# 1
# Correct answer, you have won Rs. 1000
#
#
# Question for Rs. 2000
# Usually,for which of these from a bank you would to provide a collateral?
# a.Savings account          b.Locker
# c.Loan           d.ATM card
# Enter your answer (1-4) or  0 to quit:
# 3
# Correct answer, you have won Rs. 2000
#
#
# Question for Rs. 3000
# Identify the total versions of IP.?
# a.1          b.2
# c.3           d.4
# Enter your answer (1-4) or  0 to quit:
# 2
# Correct answer, you have won Rs. 3000
#
#
# Question for Rs. 5000
# What is the full form of OSI?
# a.optical service implementation          b.open service Internet
# c.open system interconnection           d.operating system interface
# ...
